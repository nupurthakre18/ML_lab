# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.preprocessing import KBinsDiscretizer
from mlxtend.frequent_patterns import apriori, association_rules

# Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Convert numerical features into categorical using binning
# We'll use 3 bins: low, medium, high
discretizer = KBinsDiscretizer(n_bins=3, encode='ordinal', strategy='uniform')
binned_data = discretizer.fit_transform(df)

# Create a new DataFrame with categorical labels
binned_df = pd.DataFrame(binned_data, columns=df.columns)

# Map bins to readable categories (0=Low, 1=Med, 2=High)
category_map = {0.0: 'Low', 1.0: 'Med', 2.0: 'High'}
for col in binned_df.columns:
    binned_df[col] = binned_df[col].map(category_map)

# Convert each value to item format: "feature=value"
transactions = binned_df.apply(lambda row: [f"{col}={val}" for col, val in row.items()], axis=1)

# One-hot encode the transactions
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
transaction_df = pd.DataFrame(te_ary, columns=te.columns_)

# Apply Apriori algorithm
frequent_itemsets = apriori(transaction_df, min_support=0.2, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# Display results
print("Frequent Itemsets:\n", frequent_itemsets)
print("\nAssociation Rules:\n", rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Frequent Itemsets:
#       support                                           itemsets
# 0   0.306667                           (petal length (cm)=High)
# 1   0.333333                            (petal length (cm)=Low)
# 2   0.360000                            (petal length (cm)=Med)
# 3   0.320000                            (petal width (cm)=High)
# 4   0.333333                             (petal width (cm)=Low)
# 5   0.346667                             (petal width (cm)=Med)
# 6   0.346667                            (sepal length (cm)=Low)
# 7   0.466667                            (sepal length (cm)=Med)
# 8   0.313333                             (sepal width (cm)=Low)
# 9   0.586667                             (sepal width (cm)=Med)
# 10  0.273333    (petal length (cm)=High, petal width (cm)=High)
# 11  0.333333      (petal width (cm)=Low, petal length (cm)=Low)
# 12  0.300000     (sepal length (cm)=Low, petal length (cm)=Low)
# 13  0.240000      (petal length (cm)=Low, sepal width (cm)=Med)
# 14  0.313333      (petal width (cm)=Med, petal length (cm)=Med)
# 15  0.280000     (sepal length (cm)=Med, petal length (cm)=Med)
# 16  0.200000      (petal length (cm)=Med, sepal width (cm)=Low)
# 17  0.200000      (petal width (cm)=High, sepal width (cm)=Med)
# 18  0.300000      (sepal length (cm)=Low, petal width (cm)=Low)
# 19  0.240000       (petal width (cm)=Low, sepal width (cm)=Med)
# 20  0.266667      (sepal length (cm)=Med, petal width (cm)=Med)
# 21  0.200000       (petal width (cm)=Med, sepal width (cm)=Low)
# 22  0.240000      (sepal length (cm)=Low, sepal width (cm)=Med)
# 23  0.233333      (sepal length (cm)=Med, sepal width (cm)=Low)
# 24  0.206667      (sepal length (cm)=Med, sepal width (cm)=Med)
# 25  0.300000  (sepal length (cm)=Low, petal width (cm)=Low, ...
# 26  0.240000  (petal width (cm)=Low, petal length (cm)=Low, ...
# 27  0.233333  (sepal length (cm)=Low, petal length (cm)=Low,...
# 28  0.240000  (sepal length (cm)=Med, petal width (cm)=Med, ...
# 29  0.233333  (sepal length (cm)=Low, petal width (cm)=Low, ...
# 30  0.233333  (sepal length (cm)=Low, petal width (cm)=Low, ...
#
# Association Rules:
#                                            antecedents  \
# 0                            (petal length (cm)=High)
# 1                             (petal width (cm)=High)
# 2                              (petal width (cm)=Low)
# 3                             (petal length (cm)=Low)
# 4                             (sepal length (cm)=Low)
# 5                             (petal length (cm)=Low)
# 6                             (petal length (cm)=Low)
# 7                              (petal width (cm)=Med)
# 8                             (petal length (cm)=Med)
# 9                             (sepal length (cm)=Med)
# 10                            (petal length (cm)=Med)
# 11                             (sepal width (cm)=Low)
# 12                            (petal width (cm)=High)
# 13                            (sepal length (cm)=Low)
# 14                             (petal width (cm)=Low)
# 15                             (petal width (cm)=Low)
# 16                             (petal width (cm)=Med)
# 17                             (sepal width (cm)=Low)
# 18                            (sepal length (cm)=Low)
# 19                             (sepal width (cm)=Low)
# 20      (sepal length (cm)=Low, petal width (cm)=Low)
# 21     (sepal length (cm)=Low, petal length (cm)=Low)
# 22      (petal width (cm)=Low, petal length (cm)=Low)
# 23                            (sepal length (cm)=Low)
# 24                             (petal width (cm)=Low)
# 25                            (petal length (cm)=Low)
# 26      (petal width (cm)=Low, petal length (cm)=Low)
# 27       (petal width (cm)=Low, sepal width (cm)=Med)
# 28      (petal length (cm)=Low, sepal width (cm)=Med)
# 29                             (petal width (cm)=Low)
# 30                            (petal length (cm)=Low)
# 31     (sepal length (cm)=Low, petal length (cm)=Low)
# 32      (sepal length (cm)=Low, sepal width (cm)=Med)
# 33      (petal length (cm)=Low, sepal width (cm)=Med)
# 34                            (sepal length (cm)=Low)
# 35                            (petal length (cm)=Low)
# 36      (sepal length (cm)=Med, petal width (cm)=Med)
# 37     (sepal length (cm)=Med, petal length (cm)=Med)
# 38      (petal width (cm)=Med, petal length (cm)=Med)
# 39                             (petal width (cm)=Med)
# 40                            (petal length (cm)=Med)
# 41      (sepal length (cm)=Low, petal width (cm)=Low)
# 42      (sepal length (cm)=Low, sepal width (cm)=Med)
# 43       (petal width (cm)=Low, sepal width (cm)=Med)
# 44                            (sepal length (cm)=Low)
# 45                             (petal width (cm)=Low)
# 46  (sepal length (cm)=Low, petal width (cm)=Low, ...
# 47  (sepal length (cm)=Low, petal width (cm)=Low, ...
# 48  (sepal length (cm)=Low, petal length (cm)=Low,...
# 49  (petal width (cm)=Low, petal length (cm)=Low, ...
# 50      (sepal length (cm)=Low, petal width (cm)=Low)
# 51     (sepal length (cm)=Low, petal length (cm)=Low)
# 52      (sepal length (cm)=Low, sepal width (cm)=Med)
# 53      (petal width (cm)=Low, petal length (cm)=Low)
# 54       (petal width (cm)=Low, sepal width (cm)=Med)
# 55      (petal length (cm)=Low, sepal width (cm)=Med)
# 56                            (sepal length (cm)=Low)
# 57                             (petal width (cm)=Low)
# 58                            (petal length (cm)=Low)
#
#                                           consequents   support  confidence  \
# 0                             (petal width (cm)=High)  0.273333    0.891304
# 1                            (petal length (cm)=High)  0.273333    0.854167
# 2                             (petal length (cm)=Low)  0.333333    1.000000
# 3                              (petal width (cm)=Low)  0.333333    1.000000
# 4                             (petal length (cm)=Low)  0.300000    0.865385
# 5                             (sepal length (cm)=Low)  0.300000    0.900000
# 6                              (sepal width (cm)=Med)  0.240000    0.720000
# 7                             (petal length (cm)=Med)  0.313333    0.903846
# 8                              (petal width (cm)=Med)  0.313333    0.870370
# 9                             (petal length (cm)=Med)  0.280000    0.600000
# 10                            (sepal length (cm)=Med)  0.280000    0.777778
# 11                            (petal length (cm)=Med)  0.200000    0.638298
# 12                             (sepal width (cm)=Med)  0.200000    0.625000
# 13                             (petal width (cm)=Low)  0.300000    0.865385
# 14                            (sepal length (cm)=Low)  0.300000    0.900000
# 15                             (sepal width (cm)=Med)  0.240000    0.720000
# 16                            (sepal length (cm)=Med)  0.266667    0.769231
# 17                             (petal width (cm)=Med)  0.200000    0.638298
# 18                             (sepal width (cm)=Med)  0.240000    0.692308
# 19                            (sepal length (cm)=Med)  0.233333    0.744681
# 20                            (petal length (cm)=Low)  0.300000    1.000000
# 21                             (petal width (cm)=Low)  0.300000    1.000000
# 22                            (sepal length (cm)=Low)  0.300000    0.900000
# 23      (petal width (cm)=Low, petal length (cm)=Low)  0.300000    0.865385
# 24     (sepal length (cm)=Low, petal length (cm)=Low)  0.300000    0.900000
# 25      (sepal length (cm)=Low, petal width (cm)=Low)  0.300000    0.900000
# 26                             (sepal width (cm)=Med)  0.240000    0.720000
# 27                            (petal length (cm)=Low)  0.240000    1.000000
# 28                             (petal width (cm)=Low)  0.240000    1.000000
# 29      (petal length (cm)=Low, sepal width (cm)=Med)  0.240000    0.720000
# 30       (petal width (cm)=Low, sepal width (cm)=Med)  0.240000    0.720000
# 31                             (sepal width (cm)=Med)  0.233333    0.777778
# 32                            (petal length (cm)=Low)  0.233333    0.972222
# 33                            (sepal length (cm)=Low)  0.233333    0.972222
# 34      (petal length (cm)=Low, sepal width (cm)=Med)  0.233333    0.673077
# 35      (sepal length (cm)=Low, sepal width (cm)=Med)  0.233333    0.700000
# 36                            (petal length (cm)=Med)  0.240000    0.900000
# 37                             (petal width (cm)=Med)  0.240000    0.857143
# 38                            (sepal length (cm)=Med)  0.240000    0.765957
# 39     (sepal length (cm)=Med, petal length (cm)=Med)  0.240000    0.692308
# 40      (sepal length (cm)=Med, petal width (cm)=Med)  0.240000    0.666667
# 41                             (sepal width (cm)=Med)  0.233333    0.777778
# 42                             (petal width (cm)=Low)  0.233333    0.972222
# 43                            (sepal length (cm)=Low)  0.233333    0.972222
# 44       (petal width (cm)=Low, sepal width (cm)=Med)  0.233333    0.673077
# 45      (sepal length (cm)=Low, sepal width (cm)=Med)  0.233333    0.700000
# 46                             (sepal width (cm)=Med)  0.233333    0.777778
# 47                            (petal length (cm)=Low)  0.233333    1.000000
# 48                             (petal width (cm)=Low)  0.233333    1.000000
# 49                            (sepal length (cm)=Low)  0.233333    0.972222
# 50      (petal length (cm)=Low, sepal width (cm)=Med)  0.233333    0.777778
# 51       (petal width (cm)=Low, sepal width (cm)=Med)  0.233333    0.777778
# 52      (petal width (cm)=Low, petal length (cm)=Low)  0.233333    0.972222
# 53      (sepal length (cm)=Low, sepal width (cm)=Med)  0.233333    0.700000
# 54     (sepal length (cm)=Low, petal length (cm)=Low)  0.233333    0.972222
# 55      (sepal length (cm)=Low, petal width (cm)=Low)  0.233333    0.972222
# 56  (petal width (cm)=Low, petal length (cm)=Low, ...  0.233333    0.673077
# 57  (sepal length (cm)=Low, petal length (cm)=Low,...  0.233333    0.700000
# 58  (sepal length (cm)=Low, petal width (cm)=Low, ...  0.233333    0.700000
#
#         lift
# 0   2.785326
# 1   2.785326
# 2   3.000000
# 3   3.000000
# 4   2.596154
# 5   2.596154
# 6   1.227273
# 7   2.510684
# 8   2.510684
# 9   1.666667
# 10  1.666667
# 11  1.773050
# 12  1.065341
# 13  2.596154
# 14  2.596154
# 15  1.227273
# 16  1.648352
# 17  1.841244
# 18  1.180070
# 19  1.595745
# 20  3.000000
# 21  3.000000
# 22  2.596154
# 23  2.596154
# 24  3.000000
# 25  3.000000
# 26  1.227273
# 27  3.000000
# 28  3.000000
# 29  3.000000
# 30  3.000000
# 31  1.325758
# 32  2.916667
# 33  2.804487
# 34  2.804487
# 35  2.916667
# 36  2.500000
# 37  2.472527
# 38  1.641337
# 39  2.472527
# 40  2.500000
# 41  1.325758
# 42  2.916667
# 43  2.804487
# 44  2.804487
# 45  2.916667
# 46  1.325758
# 47  3.000000
# 48  3.000000
# 49  2.804487
# 50  3.240741
# 51  3.240741
# 52  2.916667
# 53  2.916667
# 54  3.240741
# 55  3.240741
# 56  2.804487
# 57  3.000000
# 58  3.000000
